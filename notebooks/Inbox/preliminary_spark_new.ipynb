# %%
import os
import pandas as pd

data_dir = "/Users/mac/Desktop/Study/Diploma/data"

# %%
tables = os.listdir(os.path.join(data_dir, "spark/raw_data"))

df = pd.read_csv(os.path.join(os.path.join(data_dir, "spark/raw_data"), tables[0]), sep=';', low_memory=False)

df.head()
# Out:
#    SparkID           INN      ShortNameEn  \
# 0  4500012  3.123104e+09  OOO "NIKASTROI"
# 1  4500012  3.123104e+09  OOO "NIKASTROI"
# 2  4500012  3.123104e+09  OOO "NIKASTROI"
# 3  4500012  3.123104e+09  OOO "NIKASTROI"
# 4  4500012  3.123104e+09  OOO "NIKASTROI"
#
#                                               okveds  OKVED  \
# 0  ['01.2', '01.50', '01.70', '02.30.13', '02.40....  96.04
# 1  ['01.2', '01.50', '01.70', '02.30.13', '02.40....  96.04
# 2  ['01.2', '01.50', '01.70', '02.30.13', '02.40....  96.04
# 3  ['01.2', '01.50', '01.70', '02.30.13', '02.40....  96.04
# 4  ['01.2', '01.50', '01.70', '02.30.13', '02.40....  96.04
#
#       Address_Region  Address_FiasRegion Address_InputDate Address_ActualDate  \
# 0  Белгородская обл.                31.0        2015-03-31         2022-04-21
# 1  Белгородская обл.                31.0        2015-03-31         2022-04-21
# 2  Белгородская обл.                31.0        2015-03-31         2022-04-21
# 3  Белгородская обл.                31.0        2015-03-31         2022-04-21
# 4  Белгородская обл.                31.0        2015-03-31         2022-04-21
#
#    OKATO_RegionCode  ... Form_1_Field_300  Form_1_Field_623 Form_1_Field_625  \
# 0                14  ...              NaN               NaN              NaN
# 1                14  ...       19522000.0           27000.0              NaN
# 2                14  ...        9153000.0            4000.0              NaN
# 3                14  ...       27864000.0           28000.0              NaN
# 4                14  ...       19522000.0           27000.0              NaN
#
#   Form_1_Field_690  Form_2_Field_010 Form_2_Field_190  Form_1_Field_610  \
# 0              NaN               NaN              NaN               NaN
# 1       19757000.0               NaN          -2000.0         7771000.0
# 2        9145000.0               NaN        -242000.0         4523000.0
# 3       29109000.0               NaN        -242000.0         9628000.0
# 4       19757000.0               NaN        -892000.0         7771000.0
#
#   Form_2_Field_100 Form_1_Field_510  Form_1_Field_590
# 0              NaN              NaN               NaN
# 1              0.0              NaN               NaN
# 2         140000.0              NaN               NaN
# 3         489000.0              NaN               NaN
# 4        1658000.0              NaN               NaN
#
# [5 rows x 58 columns]
